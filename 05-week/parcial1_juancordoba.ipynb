# %% [markdown]
# DESARROLLO PARCIAL PARTE 2
# INTEGRANTES: JUAN DIEGO CORDOBA PAJOY Y SERGIO ANDRES RIVAS OSORIO
# CASO: SE TIENEN 30 ESTUDIANTES DE LOS CUALES 10 PERDIERON LA MATERIA TENIENDO EN CUENTA QUE LA NOTA PARA PASAR ERA 3.5 O MAS

# %%
# Out:
#     ID         Nombre  Nota     Estado
# 0    1   Estudiante_1  4.36   Aprobado
# 1    2   Estudiante_2  3.64   Aprobado
# 2    3   Estudiante_3  2.07  Reprobado
# 3    4   Estudiante_4  4.61   Aprobado
# 4    5   Estudiante_5  0.35  Reprobado
# 5    6   Estudiante_6  3.61   Aprobado
# 6    7   Estudiante_7  4.94   Aprobado
# 7    8   Estudiante_8  4.97   Aprobado
# 8    9   Estudiante_9  3.87   Aprobado
# 9   10  Estudiante_10  3.79   Aprobado
# 10  11  Estudiante_11  1.03  Reprobado
# 11  12  Estudiante_12  3.55   Aprobado
# 12  13  Estudiante_13  4.07   Aprobado
# 13  14  Estudiante_14  4.52   Aprobado
# 14  15  Estudiante_15  4.96   Aprobado
# 15  16  Estudiante_16  4.49   Aprobado
# 16  17  Estudiante_17  2.53  Reprobado
# 17  18  Estudiante_18  1.85  Reprobado
# 18  19  Estudiante_19  4.23   Aprobado
# 19  20  Estudiante_20  4.60   Aprobado
# 20  21  Estudiante_21  4.14   Aprobado
# 21  22  Estudiante_22  0.59  Reprobado
# 22  23  Estudiante_23  1.59  Reprobado
# ...

# %%
# Out:
# The total number of students is: 30

# %%
# Out:
# 0     4.36
# 1     3.64
# 2     2.07
# 3     4.61
# 4     0.35
# 5     3.61
# 6     4.94
# 7     4.97
# 8     3.87
# 9     3.79
# 10    1.03
# 11    3.55
# 12    4.07
# 13    4.52
# 14    4.96
# 15    4.49
# 16    2.53
# 17    1.85
# 18    4.23
# 19    4.60
# 20    4.14
# 21    0.59
# 22    1.59
# 23    4.84
# 24    4.86
# 25    0.29
# 26    0.70
# 27    2.47
# 28    4.45
# 29    3.63
# Name: Nota, dtype: float64

# %%
# Out:
# The number of students with a final grade less than 3.5 is: 10

# %%
# Out:
# The percentage of students with a final grade less than 3.5 is: 33.33%

# %%
import matplotlib.pyplot as plt

# Calculate the number of students with a grade less than 0.35
students_less_than_0_35 = df[df['Nota'] < 0.35]
num_less_than_0_35 = len(students_less_than_0_35)

# Calculate the number of students with a grade greater than or equal to 0.35
num_greater_than_or_equal_to_0_35 = total_students - num_less_than_0_35

# Create labels and sizes for the pie chart
labels = ['Grade < 0.35', 'Grade >= 0.35']
sizes = [num_less_than_0_35, num_greater_than_or_equal_to_0_35]

# Create the pie chart
plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Students by Grade Category (< 0.35 vs >= 0.35)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
